# %%
import torch
import torch.nn as nn
import torch.optim as optim
import wikipedia
from collections import Counter

# %% [markdown]
# # Load Wikipedia data

# %%
def get_wikipedia_text(page_title):
    return wikipedia.page(page_title).content

text = get_wikipedia_text("Artificial Intelligence")

text[:100]
# Out:
# 'Artificial intelligence (AI), in its broadest sense, is intelligence exhibited by machines, particul'

# %% [markdown]
# # Tokenize text

# %%
def tokenize_text(text):
    text = text.lower().replace("\n", " ").split()
    return text

tokens = tokenize_text(text)

# %%
tokens[:10]
# Out:
# ['artificial',
#  'intelligence',
#  '(ai),',
#  'in',
#  'its',
#  'broadest',
#  'sense,',
#  'is',
#  'intelligence',
#  'exhibited']

# %% [markdown]
# # Create vocabulary

# %%
vocab = Counter(tokens)
vocab_size = 5000
most_common = vocab.most_common(vocab_size)
word_to_idx = {word: i for i, (word, _) in enumerate(most_common)}
idx_to_word = {i: word for word, i in word_to_idx.items()}

# %% [markdown]
# # Generate training data

# %%
def generate_training_data(tokens, window_size=2):
    data = []
    for i, word in enumerate(tokens):
        if word in word_to_idx:
            context = [tokens[j] for j in range(max(0, i - window_size), min(len(tokens), i + window_size + 1)) if j != i and tokens[j] in word_to_idx]
            if len(context) == 2 * window_size:  # Asegurar contexto completo
                data.append(([word_to_idx[ctx] for ctx in context], word_to_idx[word]))
    return data

training_data = generate_training_data(tokens)

# %%
training_data
# Out:
# [([27, 24, 4, 70], 1347),
#  ([24, 1347, 70, 1348], 4),
#  ([1347, 4, 1348, 1349], 70),
#  ([4, 70, 1349, 8], 1348),
#  ([70, 1348, 8, 24], 1349),
#  ([1348, 1349, 24, 769], 8),
#  ([1349, 8, 769, 12], 24),
#  ([8, 24, 12, 1350], 769),
#  ([24, 769, 1350, 298], 12),
#  ([769, 12, 298, 68], 1350),
#  ([12, 1350, 68, 770], 298),
#  ([1350, 298, 770, 15], 68),
#  ([298, 68, 15, 8], 770),
#  ([68, 770, 8, 5], 15),
#  ([770, 15, 5, 92], 8),
#  ([15, 8, 92, 2], 5),
#  ([8, 5, 2, 51], 92),
#  ([5, 92, 51, 4], 2),
#  ([92, 2, 4, 68], 51),
#  ([2, 51, 68, 252], 4),
#  ([51, 4, 252, 6], 68),
#  ([4, 68, 6, 771], 252),
#  ([68, 252, 771, 1], 6),
#  ([252, 6, 1, 509], 771),
#  ([6, 771, 509, 102], 1),
#  ([771, 1, 102, 1], 509),
#  ([1, 509, 1, 156], 102),
#  ([509, 102, 156, 6], 1),
#  ([102, 1, 6, 772], 156),
#  ([1, 156, 772, 127], 6),
#  ([156, 6, 127, 3], 772),
#  ([6, 772, 3, 510], 127),
#  ([772, 127, 510, 29], 3),
#  ([127, 3, 29, 773], 510),
#  ([3, 510, 773, 1], 29),
#  ([510, 29, 1, 43], 773),
#  ([29, 773, 43, 28], 1),
#  ([773, 1, 28, 1], 43),
#  ([1, 43, 1, 24], 28),
#  ([43, 28, 24, 3], 1),
#  ([28, 1, 3, 201], 24),
#  ([1, 24, 201, 157], 3),
#  ([24, 3, 157, 6], 201),
#  ([3, 201, 6, 379], 157),
#  ([201, 157, 379, 29], 6),
#  ([157, 6, 29, 774], 379),
#  ([6, 379, 774, 2], 29),
#  ([379, 29, 2, 775], 774),
#  ([29, 774, 775, 299], 2),
#  ([774, 2, 299, 300], 775),
#  ([2, 775, 300, 26], 299),
#  ([775, 299, 26, 127], 300),
#  ([299, 300, 127, 40], 26),
#  ([300, 26, 40, 13], 127),
#  ([26, 127, 13, 81], 40),
#  ([127, 40, 81, 1351], 13),
#  ([40, 13, 1351, 1352], 81),
#  ([13, 81, 1352, 86], 1351),
#  ([81, 1351, 86, 2], 1352),
#  ([1351, 1352, 2, 7], 86),
#  ([1352, 86, 7, 82], 2),
#  ([86, 2, 82, 253], 7),
#  ([2, 7, 253, 1353], 82),
#  ([7, 82, 1353, 59], 253),
#  ([82, 253, 59, 776], 1353),
#  ([253, 1353, 776, 103], 59),
#  ([1353, 59, 103, 128], 776),
#  ([59, 776, 128, 1354], 103),
#  ([776, 103, 1354, 511], 128),
#  ([103, 128, 511, 83], 1354),
#  ([128, 1354, 83, 777], 511),
#  ([1354, 511, 777, 12], 83),
#  ([511, 83, 12, 778], 777),
#  ([83, 777, 778, 779], 12),
#  ([777, 12, 779, 1], 778),
#  ([12, 778, 1, 1355], 779),
#  ([778, 779, 1355, 301], 1),
#  ([779, 1, 301, 380], 1355),
#  ([1, 1355, 380, 103], 301),
#  ([1355, 301, 103, 128], 380),
#  ([301, 380, 128, 1356], 103),
#  ([380, 103, 1356, 1357], 128),
#  ([103, 128, 1357, 1], 1356),
#  ([128, 1356, 1, 1358], 1357),
#  ([1356, 1357, 1358, 129], 1),
#  ([1357, 1, 129, 512], 1358),
#  ([1, 1358, 512, 103], 129),
#  ([1358, 129, 103, 1359], 512),
#  ([129, 512, 1359, 87], 103),
#  ([512, 103, 87, 1], 1359),
#  ([103, 1359, 1, 1360], 87),
#  ([1359, 87, 1360, 104], 1),
#  ([87, 1, 104, 103], 1360),
#  ([1, 1360, 103, 780], 104),
#  ([1360, 104, 780, 1], 103),
#  ([104, 103, 1, 7], 780),
#  ([103, 780, 7, 1361], 1),
#  ([780, 1, 1361, 1], 7),
#  ([1, 7, 1, 1362], 1361),
#  ([7, 1361, 1362, 781], 1),
#  ([1361, 1, 781, 1], 1362),
#  ([1, 1362, 1, 302], 781),
#  ([1362, 781, 302, 4], 1),
#  ([781, 1, 4, 513], 302),
#  ([1, 302, 513, 381], 4),
#  ([302, 4, 381, 103], 513),
#  ([4, 513, 103, 514], 381),
#  ([513, 381, 514, 1], 103),
#  ([381, 103, 1, 1363], 514),
#  ([103, 514, 1363, 93], 1),
#  ([514, 1, 93, 41], 1363),
#  ([1, 1363, 41, 7], 93),
#  ([1363, 93, 7, 86], 41),
#  ([93, 41, 86, 11], 7),
#  ([41, 7, 11, 30], 86),
#  ([7, 86, 30, 1364], 11),
#  ([86, 11, 1364, 10], 30),
#  ([11, 30, 10, 382], 1364),
#  ([30, 1364, 382, 782], 10),
#  ([1364, 10, 782, 1365], 382),
#  ([10, 382, 1365, 2], 782),
#  ([382, 782, 2, 1366], 1365),
#  ([782, 1365, 1366, 1367], 2),
#  ([1365, 2, 1367, 7], 1366),
#  ([2, 1366, 7, 35], 1367),
#  ([1366, 1367, 35, 1368], 7),
#  ([1367, 7, 1368, 84], 35),
#  ([7, 35, 84, 77], 1368),
#  ([35, 1368, 77, 383], 84),
#  ([1368, 84, 383, 202], 77),
#  ([84, 77, 202, 203], 383),
#  ([77, 383, 203, 139], 202),
#  ([383, 202, 139, 81], 203),
#  ([202, 203, 81, 7], 139),
#  ([203, 139, 7, 140], 81),
#  ([139, 81, 140, 303], 7),
#  ([81, 7, 303, 515], 140),
#  ([7, 140, 515, 304], 303),
#  ([140, 303, 304, 384], 515),
#  ([303, 515, 384, 516], 304),
#  ([515, 304, 516, 1], 384),
#  ([304, 384, 1, 305], 516),
#  ([384, 516, 305, 516], 1),
#  ([516, 1, 516, 1369], 305),
#  ([1, 305, 1369, 30], 516),
#  ([305, 516, 30, 783], 1369),
#  ([516, 1369, 783, 7], 30),
#  ([1369, 30, 7, 1370], 783),
#  ([30, 783, 1370, 204], 7),
#  ([783, 7, 204, 784], 1370),
#  ([7, 1370, 784, 2], 204),
#  ([1370, 204, 2, 7], 784),
#  ([204, 784, 7, 51], 2),
#  ([784, 2, 51, 11], 7),
#  ([2, 7, 11, 1371], 51),
#  ([7, 51, 1371, 517], 11),
#  ([51, 11, 517, 205], 1371),
#  ([11, 1371, 205, 141], 517),
#  ([1371, 517, 141, 1], 205),
#  ([517, 205, 1, 0], 141),
#  ([205, 141, 0, 43], 1),
#  ([141, 1, 43, 2], 0),
#  ([1, 0, 2, 205], 43),
#  ([0, 43, 205, 1372], 2),
#  ([43, 2, 1372, 0], 205),
#  ([2, 205, 0, 1373], 1372),
#  ([205, 1372, 1373, 141], 0),
#  ([1372, 0, 141, 2], 1373),
#  ([0, 1373, 2, 7], 141),
#  ([1373, 141, 7, 51], 2),
#  ([141, 2, 51, 82], 7),
#  ([2, 7, 82, 518], 51),
#  ([7, 51, 518, 60], 82),
#  ([51, 82, 60, 1374], 518),
#  ([82, 518, 1374, 306], 60),
#  ([518, 60, 306, 254], 1374),
#  ([60, 1374, 254, 255], 306),
#  ([1374, 306, 255, 78], 254),
#  ([306, 254, 78, 385], 255),
#  ([254, 255, 385, 519], 78),
#  ([255, 78, 519, 1], 385),
#  ([78, 385, 1, 785], 519),
#  ([385, 519, 785, 9], 1),
#  ([519, 1, 9, 786], 785),
#  ([1, 785, 786, 77], 9),
#  ([785, 9, 77, 1375], 786),
#  ([9, 786, 1375, 94], 77),
#  ([786, 77, 94, 3], 1375),
#  ([77, 1375, 3, 1376], 94),
#  ([1375, 94, 1376, 158], 3),
#  ([94, 3, 158, 386], 1376),
#  ([3, 1376, 386, 787], 158),
#  ([1376, 158, 787, 12], 386),
#  ([158, 386, 12, 5], 787),
#  ([386, 787, 5, 42], 12),
#  ([787, 12, 42, 19], 5),
#  ([12, 5, 19, 21], 42),
#  ([5, 42, 21, 46], 19),
#  ([42, 19, 46, 520], 21),
#  ([19, 21, 520, 521], 46),
#  ([21, 46, 521, 1377], 520),
#  ([46, 520, 1377, 175], 521),
#  ([520, 521, 175, 0], 1377),
#  ([521, 1377, 0, 788], 175),
#  ([1377, 175, 788, 387], 0),
#  ([175, 0, 387, 300], 788),
#  ([0, 788, 300, 3], 387),
#  ([788, 387, 3, 307], 300),
#  ([387, 300, 307, 44], 3),
#  ([300, 3, 44, 789], 307),
#  ([3, 307, 789, 7], 44),
#  ([307, 44, 7, 71], 789),
#  ([44, 789, 71, 22], 7),
#  ([789, 7, 22, 1378], 71),
#  ([7, 71, 1378, 1], 22),
#  ([71, 22, 1, 790], 1378),
#  ([22, 1378, 790, 5], 1),
#  ([1378, 1, 5, 522], 790),
#  ([1, 790, 522, 388], 5),
#  ([790, 5, 388, 2], 522),
#  ([5, 522, 2, 791], 388),
#  ([522, 388, 791, 118], 2),
#  ([388, 2, 118, 59], 791),
#  ([2, 791, 59, 1], 118),
#  ([791, 118, 1, 142], 59),
#  ([118, 59, 142, 792], 1),
#  ([59, 1, 792, 256], 142),
#  ([1, 142, 256, 523], 792),
#  ([142, 792, 523, 27], 256),
#  ([792, 256, 27, 54], 523),
#  ([256, 523, 54, 257], 27),
#  ([523, 27, 257, 1], 54),
#  ([27, 54, 1, 102], 257),
#  ([54, 257, 102, 130], 1),
#  ([257, 1, 130, 19], 102),
#  ([1, 102, 19, 793], 130),
#  ([102, 130, 793, 794], 19),
#  ([130, 19, 794, 308], 793),
#  ([19, 793, 308, 1], 794),
#  ([793, 794, 1, 524], 308),
#  ([794, 308, 524, 7], 1),
#  ([308, 1, 7, 55], 524),
#  ([1, 524, 55, 1379], 7),
#  ([524, 7, 1379, 389], 55),
#  ([7, 55, 389, 1380], 1379),
#  ([55, 1379, 1380, 1381], 389),
#  ([1379, 389, 1381, 1382], 1380),
#  ([389, 1380, 1382, 1383], 1381),
#  ([1380, 1381, 1383, 1], 1382),
#  ([1381, 1382, 1, 34], 1383),
#  ([1382, 1383, 34, 1384], 1),
#  ([1383, 1, 1384, 27], 34),
#  ([1, 34, 27, 24], 1384),
#  ([34, 1384, 24, 32], 27),
#  ([1384, 27, 32, 390], 24),
#  ([27, 24, 390, 10], 32),
#  ([24, 32, 10, 21], 390),
#  ([32, 390, 21, 391], 10),
#  ([390, 10, 391, 1385], 21),
#  ([10, 21, 1385, 4], 391),
#  ([21, 391, 4, 1386], 1385),
#  ([391, 1385, 1386, 1], 4),
#  ([1385, 4, 1, 0], 1386),
#  ([4, 1386, 0, 92], 1),
#  ([1386, 1, 92, 1387], 0),
#  ([1, 0, 1387, 119], 92),
#  ([0, 92, 119, 309], 1387),
#  ([92, 1387, 309, 1388], 119),
#  ([1387, 119, 1388, 2], 309),
#  ([119, 309, 2, 1389], 1388),
#  ([309, 1388, 1389, 392], 2),
#  ([1388, 2, 392, 70], 1389),
#  ([2, 1389, 70, 795], 392),
#  ([1389, 392, 795, 1390], 70),
#  ([392, 70, 1390, 12], 795),
#  ([70, 795, 12, 1391], 1390),
#  ([795, 1390, 1391, 2], 12),
#  ([1390, 12, 2, 1392], 1391),
#  ([12, 1391, 1392, 1], 2),
#  ([1391, 2, 1, 525], 1392),
#  ([2, 1392, 525, 2], 1),
#  ([1392, 1, 2, 1393], 525),
#  ([1, 525, 1393, 176], 2),
#  ([525, 2, 176, 10], 1393),
#  ([2, 1393, 10, 7], 176),
#  ([1393, 176, 7, 1394], 10),
#  ([176, 10, 1394, 206], 7),
#  ([10, 7, 206, 1], 1394),
#  ([7, 1394, 1, 393], 206),
#  ([1394, 206, 393, 796], 1),
#  ([206, 1, 796, 394], 393),
#  ([1, 393, 394, 143], 796),
#  ([393, 796, 143, 797], 394),
#  ([796, 394, 797, 95], 143),
#  ([394, 143, 95, 65], 797),
#  ([143, 797, 65, 28], 95),
#  ([797, 95, 28, 1395], 65),
#  ([95, 65, 1395, 395], 28),
#  ([65, 28, 395, 7], 1395),
#  ([28, 1395, 7, 798], 395),
#  ([1395, 395, 798, 31], 7),
#  ([395, 7, 31, 310], 798),
#  ([7, 798, 310, 1396], 31),
#  ([798, 31, 1396, 311], 310),
#  ([31, 310, 311, 143], 1396),
#  ([310, 1396, 143, 799], 311),
#  ([1396, 311, 799, 18], 143),
#  ([311, 143, 18, 0], 799),
#  ([143, 799, 0, 800], 18),
#  ([799, 18, 800, 1397], 0),
#  ([18, 0, 1397, 1], 800),
#  ([0, 800, 1, 12], 1397),
#  ([800, 1397, 12, 0], 1),
#  ([1397, 1, 0, 96], 12),
#  ([1, 12, 96, 801], 0),
#  ([12, 0, 801, 41], 96),
#  ([0, 96, 41, 526], 801),
#  ([96, 801, 526, 2], 41),
#  ([801, 41, 2, 802], 526),
#  ([41, 526, 802, 52], 2),
#  ([526, 2, 52, 139], 802),
#  ([2, 802, 139, 803], 52),
#  ([802, 52, 803, 4], 139),
#  ([52, 139, 4, 7], 803),
#  ([139, 803, 7, 1], 4),
#  ([803, 4, 1, 0], 7),
#  ([4, 7, 0, 92], 1),
#  ([7, 1, 92, 1398], 0),
#  ([1, 0, 1398, 804], 92),
#  ([0, 92, 804, 805], 1398),
#  ([92, 1398, 805, 806], 804),
#  ([1398, 804, 806, 4], 805),
#  ([804, 805, 4, 63], 806),
#  ([805, 806, 63, 35], 4),
#  ([806, 4, 35, 207], 63),
#  ([4, 63, 207, 176], 35),
#  ([63, 35, 176, 10], 207),
#  ([35, 207, 10, 0], 176),
#  ([207, 176, 0, 7], 10),
#  ([176, 10, 7, 1399], 0),
#  ([10, 0, 1399, 0], 7),
#  ([0, 7, 0, 807], 1399),
#  ([7, 1399, 807, 2], 0),
#  ([1399, 0, 2, 253], 807),
#  ([0, 807, 253, 87], 2),
#  ([807, 2, 87, 7], 253),
#  ([2, 253, 7, 4], 87),
#  ([253, 87, 4, 0], 7),
#  ([87, 7, 0, 1400], 4),
#  ([7, 4, 1400, 2], 0),
#  ([4, 0, 2, 0], 1400),
#  ([0, 1400, 0, 7], 2),
#  ([1400, 2, 7, 808], 0),
#  ([2, 0, 808, 1], 7),
#  ([0, 7, 1, 70], 808),
#  ([7, 808, 70, 94], 1),
#  ([808, 1, 94, 3], 70),
#  ([1, 70, 3, 527], 94),
#  ([70, 94, 527, 1], 3),
#  ([94, 3, 1, 1401], 527),
#  ([3, 527, 1401, 312], 1),
#  ([527, 1, 312, 1402], 1401),
#  ([1, 1401, 1402, 105], 312),
#  ([1401, 312, 105, 809], 1402),
#  ([312, 1402, 809, 810], 105),
#  ([1402, 105, 810, 1], 809),
#  ([105, 809, 1, 811], 810),
#  ([809, 810, 811, 4], 1),
#  ([810, 1, 4, 0], 811),
#  ([1, 811, 0, 1403], 4),
#  ([811, 4, 1403, 1], 0),
#  ([4, 0, 1, 528], 1403),
#  ([0, 1403, 528, 396], 1),
#  ([1403, 1, 396, 53], 528),
#  ([1, 528, 53, 0], 396),
#  ([528, 396, 0, 106], 53),
#  ([396, 53, 106, 2], 0),
#  ([53, 0, 2, 7], 106),
#  ([0, 106, 7, 1], 2),
#  ([106, 2, 1, 70], 7),
#  ([2, 7, 70, 387], 1),
#  ([7, 1, 387, 529], 70),
#  ([1, 70, 529, 4], 387),
#  ([70, 387, 4, 0], 529),
#  ([387, 529, 0, 1404], 4),
#  ([529, 4, 1404, 1405], 0),
#  ([4, 0, 1405, 530], 1404),
#  ([0, 1404, 530, 53], 1405),
#  ([1404, 1405, 53, 258], 530),
#  ([1405, 530, 258, 812], 53),
#  ([530, 53, 812, 3], 258),
#  ([53, 258, 3, 397], 812),
#  ([258, 812, 397, 0], 3),
#  ([812, 3, 0, 208], 397),
#  ([3, 397, 208, 1], 0),
#  ([397, 0, 1, 531], 208),
#  ([0, 208, 531, 2], 1),
#  ([208, 1, 2, 0], 531),
#  ([1, 531, 0, 813], 2),
#  ([531, 2, 813, 49], 0),
#  ([2, 0, 49, 141], 813),
#  ([0, 813, 141, 49], 49),
#  ([813, 49, 49, 0], 141),
#  ([49, 141, 0, 77], 49),
#  ([141, 49, 77, 72], 0),
#  ([49, 0, 72, 2], 77),
#  ([0, 77, 2, 814], 72),
#  ([77, 72, 814, 313], 2),
#  ([72, 2, 313, 1406], 814),
#  ([2, 814, 1406, 24], 313),
#  ([814, 313, 24, 35], 1406),
#  ([313, 1406, 35, 39], 24),
#  ([1406, 24, 39, 1407], 35),
#  ([24, 35, 1407, 84], 39),
#  ([35, 39, 84, 1408], 1407),
#  ([39, 1407, 1408, 44], 84),
#  ([1407, 84, 44, 1409], 1408),
#  ([84, 1408, 1409, 2], 44),
#  ([1408, 44, 2, 205], 1409),
#  ([44, 1409, 205, 815], 2),
#  ([1409, 2, 815, 16], 205),
#  ([2, 205, 16, 532], 815),
#  ([205, 815, 532, 6], 16),
#  ([815, 16, 6, 71], 532),
#  ([16, 532, 71, 816], 6),
#  ([532, 6, 816, 21], 71),
#  ([6, 71, 21, 131], 816),
#  ([71, 816, 131, 120], 21),
#  ([816, 21, 120, 3], 131),
#  ([21, 131, 3, 1410], 120),
#  ([131, 120, 1410, 0], 3),
#  ([120, 3, 0, 815], 1410),
#  ([3, 1410, 815, 314], 0),
#  ([1410, 0, 314, 1411], 815),
#  ([0, 815, 1411, 22], 314),
#  ([815, 314, 22, 817], 1411),
#  ([314, 1411, 817, 0], 22),
#  ([1411, 22, 0, 50], 817),
#  ([22, 817, 50, 818], 0),
#  ([817, 0, 818, 1], 50),
#  ([0, 50, 1, 1412], 818),
#  ([50, 818, 1412, 0], 1),
#  ([818, 1, 0, 819], 1412),
#  ([1, 1412, 819, 2], 0),
#  ([1412, 0, 2, 7], 819),
#  ([0, 819, 7, 315], 2),
#  ([819, 2, 315, 14], 7),
#  ([2, 7, 14, 66], 315),
#  ([7, 315, 66, 1], 14),
#  ([315, 14, 1, 533], 66),
#  ([14, 66, 533, 14], 1),
#  ([66, 1, 14, 96], 533),
#  ([1, 533, 96, 71], 14),
#  ([533, 14, 71, 88], 96),
#  ([14, 96, 88, 159], 71),
#  ([96, 71, 159, 6], 88),
#  ([71, 88, 6, 1413], 159),
#  ([88, 159, 1413, 534], 6),
#  ([159, 6, 534, 66], 1413),
#  ([6, 1413, 66, 6], 534),
#  ([1413, 534, 6, 177], 66),
#  ([534, 66, 177, 43], 6),
#  ([66, 6, 43, 95], 177),
#  ([6, 177, 95, 25], 43),
#  ([177, 43, 25, 89], 95),
#  ([43, 95, 89, 1414], 25),
#  ([95, 25, 1414, 16], 89),
#  ([25, 89, 16, 73], 1414),
#  ([89, 1414, 73, 535], 16),
#  ([1414, 16, 535, 1415], 73),
#  ([16, 73, 1415, 12], 535),
#  ([73, 535, 12, 0], 1415),
#  ([535, 1415, 0, 316], 12),
#  ([1415, 12, 316, 820], 0),
#  ([12, 0, 820, 1], 316),
#  ([0, 316, 1, 1416], 820),
#  ([316, 820, 1416, 102], 1),
#  ([820, 1, 102, 52], 1416),
#  ([1, 1416, 52, 88], 102),
#  ([1416, 102, 88, 9], 52),
#  ([102, 52, 9, 1417], 88),
#  ([52, 88, 1417, 18], 9),
#  ([88, 9, 18, 317], 1417),
#  ([9, 1417, 317, 16], 18),
#  ([1417, 18, 16, 398], 317),
#  ([18, 317, 398, 821], 16),
#  ([317, 16, 821, 1418], 398),
#  ([16, 398, 1418, 536], 821),
#  ([398, 821, 536, 23], 1418),
#  ([821, 1418, 23, 399], 536),
#  ([1418, 536, 399, 1], 23),
#  ([536, 23, 1, 524], 399),
#  ([23, 399, 524, 41], 1),
#  ([399, 1, 41, 2], 524),
#  ([1, 524, 2, 44], 41),
#  ([524, 41, 44, 159], 2),
#  ([41, 2, 159, 11], 44),
#  ([2, 44, 11, 1419], 159),
#  ([44, 159, 1419, 9], 11),
#  ([159, 11, 9, 209], 1419),
#  ([11, 1419, 209, 74], 9),
#  ([1419, 9, 74, 66], 209),
#  ([9, 209, 66, 56], 74),
#  ([209, 74, 56, 140], 66),
#  ([74, 66, 140, 25], 56),
#  ([66, 56, 25, 400], 140),
#  ([56, 140, 400, 5], 25),
#  ([140, 25, 5, 1420], 400),
#  ([25, 400, 1420, 1421], 5),
#  ([400, 5, 1421, 25], 1420),
#  ([5, 1420, 25, 207], 1421),
#  ([1420, 1421, 207, 822], 25),
#  ([1421, 25, 822, 1422], 207),
#  ([25, 207, 1422, 10], 822),
#  ([207, 822, 10, 0], 1422),
#  ([822, 1422, 0, 56], 10),
#  ([1422, 10, 56, 1423], 0),
#  ([10, 0, 1423, 121], 56),
#  ([0, 56, 121, 177], 1423),
#  ([56, 1423, 177, 537], 121),
#  ([1423, 121, 537, 43], 177),
#  ([121, 177, 43, 0], 537),
#  ([177, 537, 0, 534], 43),
#  ([537, 43, 534, 1424], 0),
#  ([43, 0, 1424, 6], 534),
#  ([0, 534, 6, 96], 1424),
#  ([534, 1424, 96, 7], 6),
#  ([1424, 6, 7, 51], 96),
#  ([6, 96, 51, 97], 7),
#  ([96, 7, 97, 823], 51),
#  ([7, 51, 823, 25], 97),
#  ([51, 97, 25, 89], 823),
#  ([97, 823, 89, 50], 25),
#  ([823, 25, 50, 2], 89),
#  ([25, 89, 2, 29], 50),
#  ([89, 50, 29, 56], 2),
#  ([50, 2, 56, 107], 29),
#  ([2, 29, 107, 1425], 56),
#  ([29, 56, 1425, 1426], 107),
#  ([56, 107, 1426, 1427], 1425),
#  ([107, 1425, 1427, 1428], 1426),
#  ([1425, 1426, 1428, 1], 1427),
#  ([1426, 1427, 1, 824], 1428),
#  ([1427, 1428, 824, 66], 1),
#  ([1428, 1, 66, 8], 824),
#  ([1, 824, 8, 21], 66),
#  ([824, 66, 21, 825], 8),
#  ([66, 8, 825, 210], 21),
#  ([8, 21, 210, 14], 825),
#  ([21, 825, 14, 60], 210),
#  ([825, 210, 60, 538], 14),
#  ([210, 14, 538, 14], 60),
#  ([14, 60, 14, 60], 538),
#  ([60, 538, 60, 538], 14),
#  ([538, 14, 538, 1], 60),
#  ([14, 60, 1, 60], 538),
#  ([60, 538, 60, 401], 1),
#  ([538, 1, 401, 402], 60),
#  ([1, 60, 402, 7], 401),
#  ([60, 401, 7, 108], 402),
#  ([401, 402, 108, 3], 7),
#  ([402, 7, 3, 1429], 108),
#  ([7, 108, 1429, 826], 3),
#  ([108, 3, 826, 827], 1429),
#  ([3, 1429, 827, 1], 826),
#  ([1429, 826, 1, 73], 827),
#  ([826, 827, 73, 1430], 1),
#  ([827, 1, 1430, 53], 73),
#  ([1, 73, 53, 259], 1430),
#  ([73, 1430, 259, 828], 53),
#  ([1430, 53, 828, 256], 259),
#  ([53, 259, 256, 60], 828),
#  ([259, 828, 60, 1431], 256),
#  ([828, 256, 1431, 11], 60),
#  ([256, 60, 11, 20], 1431),
#  ([60, 1431, 20, 4], 11),
#  ([1431, 11, 4, 1432], 20),
#  ([11, 20, 1432, 1433], 4),
#  ([20, 4, 1433, 1], 1432),
#  ([4, 1432, 1, 1434], 1433),
#  ([1432, 1433, 1434, 829], 1),
#  ([1433, 1, 829, 1435], 1434),
#  ([1, 1434, 1435, 1436], 829),
#  ([1434, 829, 1436, 109], 1435),
#  ([829, 1435, 109, 1437], 1436),
#  ([1435, 1436, 1437, 60], 109),
#  ([1436, 109, 60, 318], 1437),
#  ([109, 1437, 318, 1438], 60),
#  ([1437, 60, 1438, 1439], 318),
#  ([60, 318, 1439, 1], 1438),
#  ([318, 1438, 1, 1440], 1439),
#  ([1438, 1439, 1440, 1441], 1),
#  ([1439, 1, 1441, 23], 1440),
#  ([1, 1440, 23, 74], 1441),
#  ([1440, 1441, 74, 1442], 23),
#  ([1441, 23, 1442, 1], 74),
#  ([23, 74, 1, 34], 1442),
#  ([74, 1442, 34, 1443], 1),
#  ([1442, 1, 1443, 5], 34),
#  ([1, 34, 5, 60], 1443),
#  ([34, 1443, 60, 830], 5),
#  ([1443, 5, 830, 8], 60),
#  ([5, 60, 8, 5], 830),
#  ([60, 830, 5, 319], 8),
#  ([830, 8, 319, 2], 5),
#  ([8, 5, 2, 60], 319),
#  ([5, 319, 60, 831], 2),
#  ([319, 2, 831, 4], 60),
#  ([2, 60, 4, 5], 831),
#  ([60, 831, 5, 144], 4),
#  ([831, 4, 144, 6], 5),
#  ([4, 5, 6, 17], 144),
#  ([5, 144, 17, 13], 6),
#  ([144, 6, 13, 20], 17),
#  ([6, 17, 20, 12], 13),
#  ([17, 13, 12, 5], 20),
#  ([13, 20, 5, 1444], 12),
#  ([20, 12, 1444, 21], 5),
#  ([12, 5, 21, 1445], 1444),
#  ([5, 1444, 1445, 8], 21),
#  ([1444, 21, 8, 0], 1445),
#  ([21, 1445, 0, 160], 8),
#  ([1445, 8, 160, 2], 0),
#  ([8, 0, 2, 539], 160),
#  ([0, 160, 539, 1446], 2),
#  ([160, 2, 1446, 1447], 539),
#  ([2, 539, 1447, 1], 1446),
#  ([539, 1446, 1, 1448], 1447),
#  ([1446, 1447, 1448, 20], 1),
#  ([1447, 1, 20, 12], 1448),
#  ([1, 1448, 12, 5], 20),
#  ([1448, 20, 5, 205], 12),
#  ([20, 12, 205, 540], 5),
#  ([12, 5, 540, 2], 205),
#  ([5, 205, 2, 541], 540),
#  ([205, 540, 541, 60], 2),
#  ([540, 2, 60, 1449], 541),
#  ([2, 541, 1449, 260], 60),
#  ([541, 60, 260, 3], 1449),
#  ([60, 1449, 3, 832], 260),
#  ([1449, 260, 832, 542], 3),
#  ([260, 3, 542, 26], 832),
#  ([3, 832, 26, 10], 542),
#  ([832, 542, 10, 539], 26),
#  ([542, 26, 539, 1450], 10),
#  ([26, 10, 1450, 1451], 539),
#  ([10, 539, 1451, 1], 1450),
#  ([539, 1450, 1, 833], 1451),
#  ([1450, 1451, 833, 79], 1),
#  ([1451, 1, 79, 1452], 833),
#  ([1, 833, 1452, 1453], 79),
#  ([833, 79, 1453, 1454], 1452),
#  ([79, 1452, 1454, 403], 1453),
#  ([1452, 1453, 403, 1], 1454),
#  ([1453, 1454, 1, 1455], 403),
#  ([1454, 403, 1455, 1456], 1),
#  ([403, 1, 1456, 1], 1455),
#  ([1, 1455, 1, 1457], 1456),
#  ([1455, 1456, 1457, 60], 1),
#  ([1456, 1, 60, 53], 1457),
#  ([1, 1457, 53, 60], 60),
#  ([1457, 60, 60, 1458], 53),
#  ([60, 53, 1458, 211], 60),
#  ([53, 60, 211, 320], 1458),
#  ([60, 1458, 320, 53], 211),
#  ([1458, 211, 53, 63], 320),
#  ([211, 320, 63, 34], 53),
#  ([320, 53, 34, 80], 63),
#  ([53, 63, 80, 1459], 34),
#  ([63, 34, 1459, 834], 80),
#  ([34, 80, 834, 66], 1459),
#  ([80, 1459, 66, 1460], 834),
#  ([1459, 834, 1460, 6], 66),
#  ([834, 66, 6, 177], 1460),
#  ([66, 1460, 177, 835], 6),
#  ([1460, 6, 835, 11], 177),
#  ([6, 177, 11, 404], 835),
#  ([177, 835, 404, 405], 11),
#  ([835, 11, 405, 25], 404),
#  ([11, 404, 25, 11], 405),
#  ([404, 405, 11, 836], 25),
#  ([405, 25, 836, 1461], 11),
#  ([25, 11, 1461, 1], 836),
#  ([11, 836, 1, 38], 1461),
#  ([836, 1461, 38, 1462], 1),
#  ([1461, 1, 1462, 404], 38),
#  ([1, 38, 404, 121], 1462),
#  ([38, 1462, 121, 95], 404),
#  ([1462, 404, 95, 34], 121),
#  ([404, 121, 34, 837], 95),
#  ([121, 95, 837, 11], 34),
#  ([95, 34, 11, 1463], 837),
#  ([34, 837, 1463, 1], 11),
#  ([837, 11, 1, 41], 1463),
#  ([11, 1463, 41, 34], 1),
#  ([1463, 1, 34, 838], 41),
#  ([1, 41, 838, 1], 34),
#  ([41, 34, 1, 543], 838),
#  ([34, 838, 543, 2], 1),
#  ([838, 1, 2, 541], 543),
#  ([1, 543, 541, 175], 2),
#  ([543, 2, 175, 0], 541),
#  ([2, 541, 0, 50], 175),
#  ([541, 175, 50, 178], 0),
#  ([175, 0, 178, 56], 50),
#  ([0, 50, 56, 4], 178),
#  ([50, 178, 4, 60], 56),
#  ([178, 56, 60, 538], 4),
#  ([56, 4, 538, 11], 60),
#  ([4, 60, 11, 0], 538),
#  ([60, 538, 0, 839], 11),
#  ([538, 11, 839, 2], 0),
#  ([11, 0, 2, 544], 839),
#  ([0, 839, 544, 60], 2),
#  ([839, 2, 60, 321], 544),
#  ([2, 544, 321, 160], 60),
#  ([544, 60, 160, 2], 321),
#  ([60, 321, 2, 1464], 160),
#  ([321, 160, 1464, 837], 2),
#  ([160, 2, 837, 6], 1464),
#  ([2, 1464, 6, 0], 837),
#  ([1464, 837, 0, 1465], 6),
#  ([837, 6, 1465, 322], 0),
#  ([6, 0, 322, 545], 1465),
#  ([0, 1465, 545, 8], 322),
#  ([1465, 322, 8, 1466], 545),
#  ([322, 545, 1466, 1], 8),
#  ([545, 8, 1, 0], 1466),
#  ([8, 1466, 0, 546], 1),
#  ([1466, 1, 546, 144], 0),
#  ([1, 0, 144, 2], 546),
#  ([0, 546, 2, 50], 144),
#  ([546, 144, 50, 544], 2),
#  ([144, 2, 544, 60], 50),
#  ([2, 50, 60, 1467], 544),
#  ([50, 544, 1467, 2], 60),
#  ([544, 60, 2, 63], 1467),
#  ([60, 1467, 63, 80], 2),
#  ([1467, 2, 80, 320], 63),
#  ([2, 63, 320, 8], 80),
#  ([63, 80, 8, 30], 320),
#  ([80, 320, 30, 831], 8),
#  ([320, 8, 831, 10], 30),
#  ([8, 30, 10, 1468], 831),
#  ([30, 831, 1468, 16], 10),
#  ([831, 10, 16, 1469], 1468),
#  ([10, 1468, 1469, 6], 16),
#  ([1468, 16, 6, 25], 1469),
#  ([16, 1469, 25, 97], 6),
#  ([1469, 6, 97, 840], 25),
#  ([6, 25, 840, 1470], 97),
#  ([25, 97, 1470, 75], 840),
#  ([97, 840, 75, 8], 1470),
#  ([840, 1470, 8, 55], 75),
#  ([1470, 75, 55, 0], 8),
#  ([75, 8, 0, 323], 55),
#  ([8, 55, 323, 2], 0),
#  ([55, 0, 2, 60], 323),
#  ([0, 323, 60, 841], 2),
#  ([323, 2, 841, 0], 60),
#  ([2, 60, 0, 72], 841),
#  ([60, 841, 72, 2], 0),
#  ([841, 0, 2, 547], 72),
#  ([0, 72, 547, 60], 2),
#  ([72, 2, 60, 9], 547),
#  ([2, 547, 9, 7], 60),
#  ([547, 60, 7, 548], 9),
#  ([60, 9, 548, 14], 7),
#  ([9, 7, 14, 549], 548),
#  ([7, 548, 549, 1], 14),
#  ([548, 14, 1, 550], 549),
#  ([14, 549, 550, 14], 1),
#  ([549, 1, 14, 21], 550),
#  ([1, 550, 21, 1471], 14),
#  ([550, 14, 1471, 8], 21),
#  ([14, 21, 8, 551], 1471),
#  ([21, 1471, 551, 6], 8),
#  ([1471, 8, 6, 1472], 551),
#  ([8, 551, 1472, 1], 6),
#  ([551, 6, 1, 842], 1472),
#  ([6, 1472, 842, 157], 1),
#  ([1472, 1, 157, 4], 842),
#  ([1, 842, 4, 0], 157),
#  ([842, 157, 0, 552], 4),
#  ([157, 4, 552, 5], 0),
#  ([4, 0, 5, 843], 552),
#  ([0, 552, 843, 85], 5),
#  ([552, 5, 85, 35], 843),
#  ([5, 843, 35, 141], 85),
#  ([843, 85, 141, 16], 35),
#  ([85, 35, 16, 844], 141),
#  ([35, 141, 844, 1], 16),
#  ([141, 16, 1, 842], 844),
#  ([16, 844, 842, 157], 1),
#  ([844, 1, 157, 3], 842),
#  ([1, 842, 3, 73], 157),
#  ([842, 157, 73, 179], 3),
#  ([157, 3, 179, 1473], 73),
#  ([3, 73, 1473, 4], 179),
#  ([73, 179, 4, 553], 1473),
#  ([179, 1473, 553, 306], 4),
#  ([1473, 4, 306, 0], 553),
#  ([4, 553, 0, 85], 306),
#  ([553, 306, 85, 35], 0),
#  ([306, 0, 35, 5], 85),
#  ([0, 85, 5, 98], 35),
#  ([85, 35, 98, 845], 5),
#  ([35, 5, 845, 4], 98),
#  ([5, 98, 4, 553], 845),
#  ([98, 845, 553, 1474], 4),
#  ([845, 4, 1474, 0], 553),
#  ([4, 553, 0, 85], 1474),
#  ([553, 1474, 85, 35], 0),
#  ([1474, 0, 35, 1475], 85),
#  ([0, 85, 1475, 11], 35),
#  ([85, 35, 11, 57], 1475),
#  ([35, 1475, 57, 324], 11),
#  ([1475, 11, 324, 15], 57),
#  ([11, 57, 15, 69], 324),
#  ([57, 324, 69, 1476], 15),
#  ([324, 15, 1476, 3], 69),
#  ([15, 69, 3, 13], 1476),
#  ([69, 1476, 13, 1477], 3),
#  ([1476, 3, 1477, 1], 13),
#  ([3, 13, 1, 57], 1477),
#  ([13, 1477, 57, 324], 1),
#  ([1477, 1, 324, 15], 57),
#  ([1, 57, 15, 8], 324),
#  ([57, 324, 8, 1478], 15),
#  ([324, 15, 1478, 3], 8),
#  ([15, 8, 3, 1479], 1478),
#  ([8, 1478, 1479, 0], 3),
#  ([1478, 3, 0, 550], 1479),
#  ([3, 1479, 550, 85], 0),
#  ([1479, 0, 85, 846], 550),
#  ([0, 550, 846, 5], 85),
#  ([550, 85, 5, 180], 846),
#  ([85, 846, 180, 3], 5),
#  ([846, 5, 3, 110], 180),
#  ([5, 180, 110, 554], 3),
#  ([180, 3, 554, 1480], 110),
#  ([3, 110, 1480, 0], 554),
#  ([110, 554, 0, 1481], 1480),
#  ([554, 1480, 1481, 6], 0),
#  ([1480, 0, 6, 406], 1481),
#  ([0, 1481, 406, 132], 6),
#  ([1481, 6, 132, 407], 406),
#  ([6, 406, 407, 0], 132),
#  ([406, 132, 0, 85], 407),
#  ([132, 407, 85, 1482], 0),
#  ([407, 0, 1482, 408], 85),
#  ([0, 85, 408, 9], 1482),
#  ([85, 1482, 9, 110], 408),
#  ([1482, 408, 110, 111], 9),
#  ([408, 9, 111, 847], 110),
#  ([9, 110, 847, 15], 111),
#  ([110, 111, 15, 17], 847),
#  ([111, 847, 17, 1483], 15),
#  ([847, 15, 1483, 0], 17),
#  ([15, 17, 0, 1484], 1483),
#  ([17, 1483, 1484, 1485], 0),
#  ([1483, 0, 1485, 0], 1484),
#  ([0, 1484, 0, 848], 1485),
#  ([1484, 1485, 848, 2], 0),
#  ([1485, 0, 2, 112], 848),
#  ([0, 848, 112, 111], 2),
#  ([848, 2, 111, 1486], 112),
#  ([2, 112, 1486, 2], 111),
#  ([112, 111, 2, 0], 1486),
#  ([111, 1486, 0, 847], 2),
#  ([1486, 2, 847, 1487], 0),
#  ([2, 0, 1487, 12], 847),
#  ([0, 847, 12, 0], 1487),
#  ([847, 1487, 0, 399], 12),
#  ([1487, 12, 399, 6], 0),
#  ([12, 0, 6, 0], 399),
#  ([0, 399, 0, 555], 6),
#  ([399, 6, 555, 38], 0),
#  ([6, 0, 38, 1488], 555),
#  ([0, 555, 1488, 15], 38),
#  ([555, 38, 15, 17], 1488),
#  ([38, 1488, 17, 145], 15),
#  ([1488, 15, 145, 212], 17),
#  ([15, 17, 212, 0], 145),
#  ([17, 145, 0, 213], 212),
#  ([145, 212, 213, 18], 0),
#  ([212, 0, 18, 0], 213),
#  ([0, 213, 0, 849], 18),
#  ([213, 18, 849, 409], 0),
#  ([18, 0, 409, 1489], 849),
#  ([0, 849, 1489, 4], 409),
#  ([849, 409, 4, 850], 1489),
#  ([409, 1489, 850, 306], 4),
#  ([1489, 4, 306, 0], 850),
#  ([4, 850, 0, 85], 306),
#  ([850, 306, 85, 545], 0),
#  ([306, 0, 545, 261], 85),
#  ([0, 85, 261, 63], 545),
#  ([85, 545, 63, 0], 261),
#  ([545, 261, 0, 851], 63),
#  ([261, 63, 851, 2], 0),
#  ([63, 0, 2, 158], 851),
#  ([0, 851, 158, 213], 2),
#  ([851, 2, 213, 38], 158),
#  ([2, 158, 38, 852], 213),
#  ([158, 213, 852, 4], 38),
#  ([213, 38, 4, 50], 852),
#  ([38, 852, 50, 259], 4),
#  ([852, 4, 259, 556], 50),
#  ([4, 50, 556, 93], 259),
#  ([50, 259, 93, 0], 556),
#  ([259, 556, 0, 85], 93),
#  ([556, 93, 85, 40], 0),
#  ([93, 0, 40, 30], 85),
#  ([0, 85, 30, 13], 40),
#  ([85, 40, 13, 214], 30),
#  ([40, 30, 214, 53], 13),
#  ([30, 13, 53, 0], 214),
#  ([13, 214, 0, 554], 53),
#  ([214, 53, 554, 25], 0),
#  ([53, 0, 25, 11], 554),
#  ([0, 554, 11, 4], 25),
#  ([554, 25, 4, 853], 11),
#  ([25, 11, 853, 8], 4),
#  ([11, 4, 8, 1490], 853),
#  ([4, 853, 1490, 16], 8),
#  ([853, 8, 16, 1491], 1490),
#  ([8, 1490, 1491, 1], 16),
#  ([1490, 16, 1, 15], 1491),
#  ([16, 1491, 15, 40], 1),
#  ([1491, 1, 40, 30], 15),
#  ([1, 15, 30, 320], 40),
#  ([15, 40, 320, 9], 30),
#  ([40, 30, 9, 214], 320),
#  ([30, 320, 214, 63], 9),
#  ([320, 9, 63, 38], 214),
#  ([9, 214, 38, 854], 63),
#  ([214, 63, 854, 143], 38),
#  ([63, 38, 143, 110], 854),
#  ([38, 854, 110, 111], 143),
#  ([854, 143, 111, 213], 110),
#  ([143, 110, 213, 853], 111),
#  ([110, 111, 853, 8], 213),
#  ([111, 213, 8, 30], 853),
#  ([213, 853, 30, 1492], 8),
#  ([853, 8, 1492, 15], 30),
#  ([8, 30, 15, 181], 1492),
#  ([30, 1492, 181, 212], 15),
#  ([1492, 15, 212, 21], 181),
#  ([15, 181, 21, 213], 212),
#  ([181, 212, 213, 12], 21),
#  ([212, 21, 12, 215], 213),
#  ([21, 213, 215, 5], 12),
#  ([213, 12, 5, 410], 215),
#  ([12, 215, 410, 855], 5),
#  ([215, 5, 855, 1], 410),
#  ([5, 410, 1, 145], 855),
#  ([410, 855, 145, 1493], 1),
#  ([855, 1, 1493, 0], 145),
#  ([1, 145, 0, 554], 1493),
#  ([145, 1493, 554, 3], 0),
#  ([1493, 0, 3, 262], 554),
#  ([0, 554, 262, 47], 3),
#  ([554, 3, 47, 0], 262),
#  ([3, 262, 0, 213], 47),
#  ([262, 47, 213, 1494], 0),
#  ([47, 0, 1494, 4], 213),
#  ([0, 213, 4, 57], 1494),
#  ([213, 1494, 57, 556], 4),
#  ([1494, 4, 556, 0], 57),
#  ([4, 57, 0, 1495], 556),
#  ([57, 556, 1495, 844], 0),
#  ([556, 0, 844, 40], 1495),
#  ([0, 1495, 40, 13], 844),
#  ([1495, 844, 13, 1496], 40),
#  ([844, 40, 1496, 216], 13),
#  ([40, 13, 216, 47], 1496),
#  ([13, 1496, 47, 75], 216),
#  ([1496, 216, 75, 11], 47),
#  ([216, 47, 11, 34], 75),
#  ([47, 75, 34, 90], 11),
#  ([75, 11, 90, 16], 34),
#  ([11, 34, 16, 177], 90),
#  ([34, 90, 177, 1497], 16),
#  ([90, 16, 1497, 44], 177),
#  ([16, 177, 44, 17], 1497),
#  ([177, 1497, 17, 13], 44),
#  ([1497, 44, 13, 325], 17),
#  ([44, 17, 325, 103], 13),
#  ([17, 13, 103, 18], 325),
#  ([13, 325, 18, 1498], 103),
#  ([325, 103, 1498, 326], 18),
#  ([103, 18, 326, 1499], 1498),
#  ([18, 1498, 1499, 16], 326),
#  ([1498, 326, 16, 0], 1499),
#  ([326, 1499, 0, 85], 16),
#  ([1499, 16, 85, 17], 0),
#  ([16, 0, 17, 1500], 85),
#  ([0, 85, 1500, 113], 17),
#  ([85, 17, 113, 3], 1500),
#  ...]

# %% [markdown]
# # Generate the NN

# %%
class Word2VecCBOW(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(Word2VecCBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear_layer = nn.Linear(embedding_dim, vocab_size)
        
    def forward(self, x):
        x = self.embeddings(x)
        x = x.mean(dim=0, keepdim=True)
        x = self.linear_layer(x)
        return x

# %%
embedding_dim = 100
model = Word2VecCBOW(vocab_size, embedding_dim)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)


def train(model, data, epochs=10):
    for epoch in range(epochs):
        total_loss = 0
        for context, target in data:
            context_tensor = torch.tensor(context, dtype=torch.long)
            target_tensor = torch.tensor([target], dtype=torch.long)
            
            optimizer.zero_grad()
            output = model(context_tensor)
            loss = criterion(output, target_tensor)
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
        print(f"Epoch {epoch + 1}, Loss: {total_loss:.4f}")

train(model, training_data[:10000])
# Out:
# Epoch 1, Loss: 86958.2021
# Epoch 2, Loss: 46801.0799
# Epoch 3, Loss: 27634.4713
# Epoch 4, Loss: 17479.6352
# Epoch 5, Loss: 14728.0092
# Epoch 6, Loss: 14305.1192
# Epoch 7, Loss: 14412.7092
# Epoch 8, Loss: 14130.4724
# Epoch 9, Loss: 13737.4084
# Epoch 10, Loss: 14128.5080

# %% [markdown]
# # Generate embeddings

# %%
word = "intelligence"
if word in word_to_idx:
    word_embedding = model.embeddings(torch.tensor(word_to_idx[word])).detach().numpy()
    print(f"Embedding para '{word}': {word_embedding}")
# Out:
# Embedding para 'intelligence': [ 1.66257834e+00 -1.79885834e-01 -2.33604097e+00  1.17206061e+00
#  -1.23621392e+00 -1.79409730e+00  4.05841589e-01 -5.10636687e-01
#  -1.81689894e+00  6.83415011e-02 -1.29402494e+00 -4.67476797e+00
#  -5.02744973e-01 -6.98089361e-01  2.72539347e-01 -1.31165564e+00
#   1.40020549e+00  8.11261058e-01  2.06933570e+00 -8.65141213e-01
#   8.12190950e-01 -1.31560326e+00 -2.36804292e-01  3.48418951e-01
#   1.31253934e+00  1.93441558e+00 -7.50973403e-01  5.55907845e-01
#  -1.98047578e+00  5.86264534e-03 -1.11938335e-01  3.71036112e-01
#   7.21017838e-01 -1.60618305e+00  4.72870409e-01  1.12088752e+00
#  -2.86125016e+00 -1.59413815e+00 -6.50377989e-01 -2.07033610e+00
#  -5.06077588e-01  1.38210952e-01  1.09794033e+00  9.59819317e-01
#  -1.14853942e+00 -5.31218827e-01 -1.45121908e+00 -5.89357555e-01
#  -3.85101414e+00  8.02872360e-01  1.65412283e+00  2.59400904e-01
#   1.08029521e+00 -5.39861739e-01  2.36301243e-01 -9.73361313e-01
#  -3.39813352e+00 -6.56648993e-01 -1.60537446e+00 -2.39228338e-01
#  -1.29811263e+00  1.05714846e+00 -1.16910183e+00  1.54257011e+00
#  -2.91974401e+00 -2.12004232e+00 -1.28233743e+00  1.51403713e+00
#  -8.87253657e-02  9.18535590e-02  8.26199353e-01  5.90084374e-01
#  -4.48480940e+00  1.65190721e+00 -9.78547856e-02  3.39942425e-01
#   1.69815588e+00 -9.70674396e-01 -4.96522248e-01 -7.22263932e-01
#   1.48203218e+00  2.23110509e+00 -2.99002099e+00  2.22454235e-01
#   6.49580657e-01  3.58566735e-03  1.71064055e+00 -2.92478383e-01
#   5.30302465e-01 -7.31016695e-01 -5.64209461e-01 -1.24680984e+00
#   1.93705106e+00  2.57176280e+00  8.65212262e-01  1.37645209e+00
#  -1.38820839e+00  1.44059372e+00  1.15713680e+00  1.16452372e+00]
